# %% [markdown]
# In this notebook we implement a clustering machine learning model to cluster job positing as been related or not related to machine learning.

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (520 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.1/520.1 kB 2.7 MB/s eta 0:00:000:00:010:00:01:01
# Requirement already satisfied: pillow in /home/ulrich/venv/datascience/lib/python3.8/site-packages (from wordcloud) (9.3.0)
# Requirement already satisfied: numpy>=1.6.1 in /home/ulrich/venv/datascience/lib/python3.8/site-packages (from wordcloud) (1.23.2)
# Requirement already satisfied: matplotlib in /home/ulrich/venv/datascience/lib/python3.8/site-packages (from wordcloud) (3.6.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ulrich/venv/datascience/lib/python3.8/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/ulrich/venv/datascience/lib/python3.8/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ulrich/venv/datascience/lib/python3.8/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/ulrich/venv/datascience/lib/python3.8/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ulrich/venv/datascience/lib/python3.8/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ulrich/venv/datascience/lib/python3.8/site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ulrich/venv/datascience/lib/python3.8/site-packages (from matplotlib->wordcloud) (1.0.6)
# Requirement already satisfied: six>=1.5 in /home/ulrich/venv/datascience/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score, accuracy_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np
import re
from wordcloud import WordCloud

# %%
file_path = "~/Downloads/postings.csv"  # This assumes you have this file at this location

# %% [markdown]
# Load the dataset and print some descritptive statistics

# %%
job_postings = pd.read_csv(file_path)
job_postings.head()
# Out:
#      job_id            company_name  \
# 0    921716   Corcoran Sawyer Smith
# 1   1829192                     NaN
# 2  10998357  The National Exemplar
# 3  23221523  Abrams Fensterman, LLP
# 4  35982263                     NaN
#
#                                                title  \
# 0                              Marketing Coordinator
# 1                  Mental Health Therapist/Counselor
# 2                        Assitant Restaurant Manager
# 3  Senior Elder Law / Trusts and Estates Associat...
# 4                                 Service Technician
#
#                                          description  max_salary pay_period  \
# 0  Job descriptionA leading real estate firm in N...        20.0     HOURLY
# 1  At Aspen Therapy and Wellness , we are committ...        50.0     HOURLY
# 2  The National Exemplar is accepting application...     65000.0     YEARLY
# 3  Senior Associate Attorney - Elder Law / Trusts...    175000.0     YEARLY
# 4  Looking for HVAC service tech with experience ...     80000.0     YEARLY
#
#             location  company_id  views  med_salary  ...        expiry  \
# 0      Princeton, NJ   2774458.0   20.0         NaN  ...  1.715990e+12
# 1   Fort Collins, CO         NaN    1.0         NaN  ...  1.715450e+12
# 2     Cincinnati, OH  64896719.0    8.0         NaN  ...  1.715870e+12
# 3  New Hyde Park, NY    766262.0   16.0         NaN  ...  1.715488e+12
# 4     Burlington, IA         NaN    3.0         NaN  ...  1.716044e+12
#
#   closed_time  formatted_experience_level  \
# 0         NaN                         NaN
# 1         NaN                         NaN
# 2         NaN                         NaN
# 3         NaN                         NaN
# 4         NaN                         NaN
#
#                                          skills_desc   listed_time  \
# 0  Requirements: \n\nWe are seeking a College or ...  1.713398e+12
# 1                                                NaN  1.712858e+12
# 2  We are currently accepting resumes for FOH - A...  1.713278e+12
# 3  This position requires a baseline understandin...  1.712896e+12
# 4                                                NaN  1.713452e+12
#
#   posting_domain sponsored  work_type  currency  compensation_type
# 0            NaN         0  FULL_TIME       USD        BASE_SALARY
# 1            NaN         0  FULL_TIME       USD        BASE_SALARY
# 2            NaN         0  FULL_TIME       USD        BASE_SALARY
# 3            NaN         0  FULL_TIME       USD        BASE_SALARY
# 4            NaN         0  FULL_TIME       USD        BASE_SALARY
#
# [5 rows x 28 columns]

# %% [markdown]
# Check Nan values

# %%
job_postings.isna().sum()
# Out:
# job_id                             0
# company_name                    1719
# title                              0
# description                        7
# max_salary                     94056
# pay_period                     87776
# location                           0
# company_id                      1717
# views                           1689
# med_salary                    117569
# min_salary                     94056
# formatted_work_type                0
# applies                       100529
# original_listed_time               0
# remote_allowed                108603
# job_posting_url                    0
# application_url                36665
# application_type                   0
# expiry                             0
# closed_time                   122776
# formatted_experience_level     29409
# skills_desc                   121410
# listed_time                        0
# posting_domain                 39968
# sponsored                          0
# work_type                          0
# currency                       87776
# compensation_type              87776
# dtype: int64

# %% [markdown]
# For the analysis we only use the job title and the job description so we will drop rows with empty titles and descriptions.

# %%
job_postings = job_postings.dropna(subset=['title', 'description'])

# %%
job_titles = job_postings['title']
job_descriptions = job_postings['description']

# %%
# Remove html tags and turn all text to lower case letters
def preprocess_text(text):
    text = re.sub(r'<.*?>', '', text)
    text = re.sub(r'[^A-Za-z\s]', '', text)
    text = text.lower()
    return text

# %% [markdown]
# We use the preprocess_text function to cleanup the titles, then we will merge the title and the descriptions

# %%
job_titles_cleaned = job_titles.apply(preprocess_text)
job_descriptions_cleaned = job_descriptions.apply(preprocess_text)

# Combine titles and descriptions
combined_texts = job_titles_cleaned + ' ' + job_descriptions_cleaned

# %% [markdown]
# We will create a new features that checks if we have the below machine learning / data science related keywords in the title or job description

# %%
# Feature Extraction
ml_ai_keywords = ['machine learning', 'artificial intelligence', 'deep learning', 'neural networks', 'data science', 'computer vision', 'nlp', 'natural language processing']

def extract_features(texts):
    features = []
    for text in texts:
        feature_vector = []
        for keyword in ml_ai_keywords:
            feature_vector.append(int(keyword in text))
        features.append([sum(feature_vector)])
    return np.array(features)

# %%
job_features = extract_features(combined_texts)

# Text Vectorization
vectorizer = TfidfVectorizer(max_features=100)
tfidf_vectors = vectorizer.fit_transform(combined_texts).toarray()

# Combine TF-IDF vectors with extracted features
combined_vectors = np.hstack((tfidf_vectors, job_features))

# key words labels

ml_ai_labels = np.array(job_features > 0, dtype=float) 

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(combined_vectors, ml_ai_labels, test_size=0.3, random_state=42)

# %%
X_train.shape
# Out:
# (86689, 101)

# %%
# Clustering
num_clusters = 2  # We assume two clusters: ML-related and non-ML-related
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(X_train)
train_labels = kmeans.labels_

# Predict clusters for the test set
test_labels = kmeans.predict(X_test)

# Evaluation Metrics on the Training Set
silhouette_avg_train = silhouette_score(X_train, train_labels)
calinski_harabasz_train = calinski_harabasz_score(X_train, train_labels)
davies_bouldin_train = davies_bouldin_score(X_train, train_labels)

print(f'Training Set - Silhouette Score: {silhouette_avg_train}')
print(f'Training Set - Calinski-Harabasz Index: {calinski_harabasz_train}')
print(f'Training Set - Davies-Bouldin Index: {davies_bouldin_train}')
# Out:
# Training Set - Silhouette Score: 0.5512840964115753
# Training Set - Calinski-Harabasz Index: 16832.94833628785
# Training Set - Davies-Bouldin Index: 0.9275255560458189

# %% [markdown]
# Our Silhouette score is slight greater than 0.5. This is indicates acceptable clustering results but we need to figure ways of improving the clusting model. Additionaly the Davies-Bouldin Index is 0.927 on the training set. This confirms the clustering is acceptable but can still be improve to push this metric to much more favourable values < 0.5. The Calinski-Harabasz index is quite which is good but doesn't provide much information in this case

# %%
# Evaluation Metrics on the Test Set
silhouette_avg_test = silhouette_score(X_test, test_labels)
calinski_harabasz_test = calinski_harabasz_score(X_test, test_labels)
davies_bouldin_test = davies_bouldin_score(X_test, test_labels)

print(f'Test Set - Silhouette Score: {silhouette_avg_test}')
print(f'Test Set - Calinski-Harabasz Index: {calinski_harabasz_test}')
print(f'Test Set - Davies-Bouldin Index: {davies_bouldin_test}')
# Out:
# Test Set - Silhouette Score: 0.5521469340895414
# Test Set - Calinski-Harabasz Index: 6988.890951145042
# Test Set - Davies-Bouldin Index: 0.9308333965838931

# %% [markdown]
# We have similar Sihouette and Davies-Bouldin index scores to for the training and test set indicating the clustering model is not just overfiting to the dataset.

# %% [markdown]
# ### Visualising the clustering

# %%
# Visualization of Training Set
pca = PCA(n_components=2)
reduced_train_vectors = pca.fit_transform(X_train)

plt.figure(figsize=(10, 7))
plt.scatter(reduced_train_vectors[:, 0], reduced_train_vectors[:, 1], c=train_labels, cmap='viridis')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('Training Set - Job Postings Clustering')
plt.colorbar()
plt.show()

# %%
# Visualization of Test Set
reduced_test_vectors = pca.transform(X_test)

plt.figure(figsize=(10, 7))
plt.scatter(reduced_test_vectors[:, 0], reduced_test_vectors[:, 1], c=test_labels, cmap='viridis')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('Test Set - Job Postings Clustering')
plt.colorbar()
plt.show()

# %%
# Determine which label belongs to which class
acc = accuracy_score(y_train, train_labels)
acc2 = accuracy_score(1-y_train, train_labels)
print(acc, acc2)
# Out:
# 0.0 1.0

# %% [markdown]
# From the computation from the previous cell, the 0 -> ML and 1 -> Non ML

# %%
# Analyze the clusters to determine which is ML-related and which is non-ML-related
df_train = pd.DataFrame(y_train, columns=["ml_ai_keyword"])
df_train['Cluster'] = train_labels


df_test = pd.DataFrame(y_test, columns=["ml_ai_keyword"])
df_test['Cluster'] = test_labels


# Assigning labels to clusters for interpretation
cluster_label_mapping = {0: 'ML', 1: 'Non-ML'}
df_train['Cluster Label'] = df_train['Cluster'].map(cluster_label_mapping)
df_test['Cluster Label'] = df_test['Cluster'].map(cluster_label_mapping)

# %%
# Create a word cloud for the ML-related job postings in the test set
ml_related_jobs = job_postings.iloc[df_train.index[train_labels == 0]]
ml_related_texts = ml_related_jobs['title'] # + ' ' + ml_related_jobs['description']
combined_ml_related_texts = ' '.join(ml_related_texts.apply(preprocess_text))

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(combined_ml_related_texts)

# Display the word cloud
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for ML-related Job Postings')
plt.show()

# %%
# Print original job postings with their assigned cluster labels for test set
for i, job in job_postings.iterrows():
    if i in df_test.index and df_test.loc[i, 'Cluster Label'] == 'ML':
        print(f"Job Title: {job['title']}, Cluster: {df_test.loc[i, 'Cluster Label']}")
# Out:
# Job Title: Worship Leader, Cluster: ML
# Job Title: Assistant Director, Cluster: ML
# Job Title: Senior Software Engineer, Cluster: ML
# Job Title: Pediatric Occupational Therapy, Cluster: ML
# Job Title: Inbound Sales & Onboarding Specialist, Cluster: ML
# Job Title: Histology Supervisor, Cluster: ML
# Job Title: Project Estimator, Cluster: ML
# Job Title: FL Bar Associate Attorney Tax, Trusts, and Estates, Cluster: ML
# Job Title: Service Specialist, Cluster: ML
# Job Title: 🚀 Join Our Team as a Senior iOS Developer at ABHI IT SYSTEMS INC 🌐 🚀, Cluster: ML
# Job Title: Mentorship Case Manager, Cluster: ML
# Job Title: Pilot in Command Phenom 300, Cluster: ML
# Job Title: Senior Data Engineer/Analyst - Full Time, Cluster: ML
# Job Title: PeopleSoft FSCM Functional Analyst - GL and KK modules, Cluster: ML
# Job Title: IAM Security Specialist, Cluster: ML
# Job Title: Part Time Driver (Manheim), Cluster: ML
# Job Title: Junior Engineer - [Full Remote], Cluster: ML
# Job Title: Education Budget Manager , Cluster: ML
# Job Title: Manager, Corporate Vertical Sales, Cluster: ML
# Job Title: Administrative Assistant, Cluster: ML
# Job Title: Maintenance Technician, Cluster: ML
# Job Title: General Operator 3rd Shift, Cluster: ML
# Job Title: Software Engineer with Vue JS., Cluster: ML
# Job Title: User Experience Designer, Cluster: ML
# Job Title: Senior Business Analyst, Cluster: ML
# Job Title: Medical Coder, Cluster: ML
# Job Title: Information Security Manager, Cluster: ML
# Job Title: SAP S/4 Cloud Delivery Lead (Automotive Car Motor/Vehicle Manufacturing experience) , Cluster: ML
# Job Title: Store Loss Prevention Investigator, Cluster: ML
# Job Title: Validation Analyst, Cluster: ML
# Job Title: Assistant Claims Examiner (Onsite Irving, Texas), Cluster: ML
# Job Title: Hiller Manufacturing Manager, Cluster: ML
# Job Title: Bearing Technician, Cluster: ML
# Job Title: Windows Engineer (DMX files) :: Hybrid role in San Diego, CA - Locals Only, Cluster: ML
# Job Title: Financial Consultant, Cluster: ML
# Job Title: Retail Sales Print & Marketing Associate, Cluster: ML
# Job Title: Financial Accountant, Cluster: ML
# Job Title: Oracle Finance  Fusion Lead, Cluster: ML
# Job Title: Project Architect, Mixed-Use, Cluster: ML
# Job Title: Franchise Training Coordinator, Cluster: ML
# Job Title: Nurse - RN - Emergency Medicine - Pediatric, Cluster: ML
# Job Title: Company Driver, Cluster: ML
# Job Title: Business System Analyst IT Applications -merchandise planning, Cluster: ML
# Job Title: Athletic Trainer, Cluster: ML
# Job Title: E-Commerce Leader - NA, Cluster: ML
# Job Title: ForgeRock Developer, Cluster: ML
# Job Title: Director, Design Verification Engineering, Cluster: ML
# Job Title: Registered Nurse (RN) – Breast Surgical Oncology Clinic  - $40.00-$63.00 / hour - Full Time - Enjoy up to a $10k Sign-on Bonus*, Cluster: ML
# Job Title: Quality Control Technician, Cluster: ML
# Job Title: Laborer II- Drill Operator, Cluster: ML
# Job Title: Manufacturing Engineering Technician, Cluster: ML
# Job Title: Assistant Store Manager, Cluster: ML
# Job Title: Director, Marketing Automation & Operations, Cluster: ML
# Job Title: Program Manager, Cluster: ML
# Job Title: Account Executive, Cluster: ML
# Job Title: IT Associate, EMR Training, Cluster: ML
# Job Title: Sr. Android Developer, Cluster: ML
# Job Title: Network Security Specialist, Cluster: ML
# Job Title: Director-FP&A, Cluster: ML
# Job Title: Reltio Business System Analyst, Cluster: ML
# Job Title: Sales Specialist, Cluster: ML
# Job Title: Lead Java Developer, Cluster: ML
# Job Title: Scrum Master / Product Owner, Cluster: ML
# Job Title: Assistant Plant Manager, Cluster: ML
# Job Title: Stacker, Cluster: ML
# Job Title: AVP & Assistant General Ledger Manager, Cluster: ML
# Job Title: Employee Benefits Account Manager Team Lead, Cluster: ML
# Job Title: Software Engineer, Cluster: ML
# Job Title: Diesel Technician/Mechanic III - Entry Level, Cluster: ML
# Job Title: Nurse - RN - Labor and Delivery / L&D, Cluster: ML
# Job Title: Clinical Nurse Attending CVICU, Cluster: ML
# Job Title: Supplier Quality Engineer, Cluster: ML
# Job Title: Laborer, Cluster: ML
# Job Title: Physical Therapist / PT - Rehab, Cluster: ML
# Job Title: Entry Level Manufacturing Positions, Cluster: ML
# Job Title: Senior Financial Analyst, Cluster: ML
# Job Title: Nurse - CNA - LTC, Cluster: ML
# Job Title: Stocker / Cashier, Cluster: ML
# Job Title: Senior Sales Associate - Keyholder, Cluster: ML
# Job Title: Registered Nurse- Part Time Days, Cluster: ML
# Job Title: Development Coordinator (Onsite), Cluster: ML
# Job Title: Business Relations Senior Analyst, Cluster: ML
# Job Title: GN21 Team Leader Production-DL MSLN, Cluster: ML
# Job Title: Certified Nursing Assistant (CNA) $3000 Sign On Bonus, Cluster: ML
# Job Title: Group Retirement 403b Desk – Onboarding, Cluster: ML
# Job Title: Licensed Physical Therapist Assistant, Cluster: ML
# Job Title: Registered Nurse (RN) Infection Preventionist, Cluster: ML
# Job Title: Registered Dietitian, Cluster: ML
# Job Title: QC Analyst (Micro), Cluster: ML
# Job Title: Registered Occupational Therapist (OT) Agency Free Facility, Cluster: ML
# Job Title: Senior Director, Reporting & Business Analytics, Cluster: ML
# Job Title: Patient Care Technician, Senior - Radiology, Cluster: ML
# Job Title: Receptionist, Cluster: ML
# Job Title: PFS Shift Supervisor, Cluster: ML
# Job Title: Materials Team Lead, Cluster: ML
# Job Title: Assistant Manager Student Services, Cluster: ML
# Job Title: Risk Manager Registered Nurse, Cluster: ML
# Job Title: Hairstylist, Cluster: ML
# Job Title: Design Engineer OSS / Network - Alpharetta, GA, Cluster: ML
# Job Title: Assistant Manager Student Services, Cluster: ML
# Job Title: Nutrition Specialist, Cluster: ML
# Job Title: Contract Administrator – Climate Action, Sustainability and Resiliency, Cluster: ML
# Job Title: Kitchen Steward, Cluster: ML
# Job Title: Sales Manager, Cluster: ML
# Job Title: Sales Manager, Cluster: ML
# Job Title: Sales Manager, Cluster: ML
# Job Title: Travel Nurse RN - Med/Surg - $2,062 per week in Globe, AZ, Cluster: ML
# Job Title: CLINIC STAFF TRAINER (CERTIFIED MEDICAL ASSISTANT), Cluster: ML
# Job Title: Recovery Navigator - Hub & Spoke Program, Cluster: ML
# Job Title: Sales Manager, Cluster: ML
# Job Title: Medical Assistant- Ocala 200 $1,000 Sign on Bonus, Cluster: ML
# Job Title: Group Facilitator (Mental Health Facility), Cluster: ML
# Job Title: Business Planner, Cluster: ML
# Job Title: Certified Nursing Assistant (CNA), Cluster: ML
# Job Title: C-Suite Executive Assistant, Cluster: ML
# Job Title: Marketing Intern, Cluster: ML
# Job Title: Registered Nurse - Med/Surg N3A - Day/Night, Cluster: ML
# Job Title: Construction Project Manager, Cluster: ML
# Job Title: Auto Glass Installation Technician Trainee, Cluster: ML
# Job Title: Social Worker - Lvl II, Cluster: ML
# Job Title: Director Regional Health, Safety, Environmental, Cluster: ML
# Job Title: Certified Surgical Technologist - ENDO, Cluster: ML
# Job Title: Porter, Cluster: ML
# Job Title: Account Executive, Development, Cluster: ML
# Job Title: Per Diem Pharmacy Technician I, Cluster: ML
# Job Title: UX Designer - Kohler Ventures, Cluster: ML
# Job Title: Training Support Specialist, Cluster: ML
# Job Title: System Security Architect, Cluster: ML
# Job Title: Branch Operations Manager - Lake City Branch, Cluster: ML
# Job Title: Electrical Engineer, Cluster: ML
# Job Title: Facilities and Maintenance Coordinator, Cluster: ML
# Job Title: Marketing Events & Promotions, Cluster: ML
# Job Title: Senior Design Engineer, Cluster: ML
# Job Title: Lead DevOps Engineer, Cluster: ML
# Job Title: FEMA PA-TAC (Public Assistance) Specialist, Cluster: ML
# Job Title: Math Teacher- Valley High School Job ID 30176 (2024-2025) - Start Time 8:40, Cluster: ML
# Job Title: Front End Engineer II, AWS Accessibility, Cluster: ML
# Job Title: Field Service Electrical Lead, Cluster: ML
# Job Title: Travel Nurse RN - Med/Surg - $2,161 per week in Rockford, IL, Cluster: ML
# Job Title: Commercial Plumber, Cluster: ML
# Job Title: Driver Manager, Cluster: ML
# Job Title: Outreach and Admission Counselor, Cluster: ML
# Job Title: LICENSED PRACTICAL NURSE (LPN) - YADKIN NURSING CARE CENTER, Cluster: ML
# Job Title: Manufacturing Operator, Cluster: ML
# Job Title: REGISTERED NURSE - MARY GRAN, Cluster: ML
# Job Title: Flight Nurse, Cluster: ML
# Job Title: Data Analyst-WA, Cluster: ML
# Job Title: Reading Instructor, Cluster: ML
# Job Title: CERTIFIED OCCUPATIONAL THERAPY ASSISTANT (COTA) - LIBERTY COMMONS OF ROWAN COUNTY, Cluster: ML
# Job Title: LICENSED PRACTICAL NURSE - LPN - QUAIL HAVEN, Cluster: ML
# Job Title: Commercial Roofer, Cluster: ML
# Job Title: Lead Propane CDL Delivery Driver, Cluster: ML
# Job Title: Service Desk Technician, Cluster: ML
# Job Title: Production Supervisor - 2nd Shift (Fall River, WI), Cluster: ML
# Job Title: LICENSED PRACTICAL NURSE (LPN) - THE FOLEY CENTER AT CHESTNUT RIDGE, Cluster: ML
# Job Title: HOME CARE REGISTERED NURSE, Cluster: ML
# Job Title: Assistant Scientist, Cluster: ML
# Job Title: CERTIFIED NURSING ASSISTANT - CNA - TEMPLETON OF CARY, Cluster: ML
# Job Title: HOSPICE REGISTERED NURSE, Cluster: ML
# Job Title: SPEECH LANGUAGE PATHOLOGIST (SLP) - WOODHAVEN, Cluster: ML
# Job Title: Oracle Data Integrator - C2C Contract Position, Cluster: ML
# Job Title: Senior Full Stack Software Engineer, Cluster: ML
# Job Title: Restaurant General Manager, Cluster: ML
# Job Title: Major Gifts and Corporate Officer, Cluster: ML
# Job Title: Estimator, Cluster: ML
# Job Title: Finisher, Cluster: ML
# Job Title: Caregiver, Cluster: ML
# Job Title: ARNP-Med SPA, Cluster: ML
# Job Title: Health Safety Environment Officer, Cluster: ML
# Job Title: Network Security Consultant, Cluster: ML
# Job Title: Sales Account Executive, Cluster: ML
# Job Title: Data_Entry_Clerk/Data_Migration_Specialist, Cluster: ML
# Job Title: Distribution Center IT Systems Associate, Cluster: ML
# Job Title: Lead Software Engineer, Backend (Java, Go), Cluster: ML
# Job Title: Security Officer - Guard Shack, Cluster: ML
# Job Title: Senior Associate, Treasury Accounting, Cluster: ML
# Job Title: Staff Nurse - Medicine/Surgery, Cluster: ML
# Job Title: PeopleSoft Finance Techno-Functional Consultant, Cluster: ML
# Job Title: Metrology Engineer, Cluster: ML
# Job Title: Store Associate - Sales, Cluster: ML
# Job Title: Branch Office Administrator, Cluster: ML
# Job Title: Front Office Manager , Cluster: ML
# Job Title: Dishwasher, Cluster: ML
# Job Title: Radiation Oncologist, Cluster: ML
# Job Title: Senior Project Manager, Cluster: ML
# Job Title: Tower Technician III - Construction, Cluster: ML
# Job Title: Store Manager - SoHo Flagship, Cluster: ML
# Job Title: Engineering Manager, Frontend, Cluster: ML
# Job Title: Population Health Navigator-Boston Region, Cluster: ML
# Job Title: Contract Engineer Embedded Sr., Cluster: ML
# Job Title: Supervisor-Food + Nutrition (Patient Care Services), Cluster: ML
# Job Title: GTH AS Administrative Technical Reviewer, Cluster: ML
# Job Title: Hiring CSR's - $21/hour - Starting 4/22, Cluster: ML
# Job Title: Maintenance Technician I, Cluster: ML
# Job Title: Sales Representative Lead, Cluster: ML
# Job Title: Clinical Adoption Data Scientist, Cluster: ML
# Job Title: Sales Advisor - Intel Computers, Cluster: ML
# Job Title: Development/Delivery Manager, Cluster: ML
# Job Title: Production Supervisor - Ready To Cook (Evening Shift), Cluster: ML
# Job Title: Surgical Technologist III, Cluster: ML
# Job Title: Nurse Practitioner need in Salem, OR, Cluster: ML
# Job Title: Program Manager II WFH, Cluster: ML
# Job Title: Group Account Director, Cluster: ML
# Job Title: Contact Center Quality Assurance Specialist, Cluster: ML
# Job Title: Assistant Project Controls Consultant, Cluster: ML
# Job Title: Billing Specialist, Cluster: ML
# Job Title: Front Desk Agent, Cluster: ML
# Job Title: Senior Accountant, Cluster: ML
# Job Title: Sales Lead, Cluster: ML
# Job Title: Operations Manager Cincinnati Streetcar, Cluster: ML
# Job Title: Cash Analyst, Cluster: ML
# Job Title: Registered Nurse - Endocrinology, Cluster: ML
# Job Title: RN Case Manager, Cluster: ML
# Job Title: Locum Hospitalist Physician job in Springfield, TN - Make $180/hr - $200/hr, Cluster: ML
# Job Title: Part Time Sales Associate - Chandler Fashion Center, Cluster: ML
# Job Title: Sales Executive, Cluster: ML
# Job Title: Administrative_Asistant, Cluster: ML
# Job Title: Team Lead, Cluster: ML
# Job Title: Security Manager - Vulnerability Scanning, Cluster: ML
# Job Title: Senior Property Accountant, Cluster: ML
# Job Title: Personal Banker, Cluster: ML
# Job Title: Home Daily CDL A OR B Delivery Driver Full Benefits, Cluster: ML
# Job Title: Operations Manager, Cluster: ML
# Job Title: Retail Sales Associate Golf, Cluster: ML
# Job Title: Associate Merchant (all brands), Cluster: ML
# Job Title: Digital Marketing Intern, Cluster: ML
# Job Title: Receptionist, Cluster: ML
# Job Title: Retail Cashier, Cluster: ML
# Job Title: Class A Delivery Driver, Cluster: ML
# Job Title: CDL Class A - Delivery Truck Driver (entry level), Cluster: ML
# Job Title: Receptionist, Cluster: ML
# Job Title: Human Resources Director, Cluster: ML
# Job Title: Players Club Representative PT $20.00 Hourly, Cluster: ML
# Job Title: Receptionist, Cluster: ML
# Job Title: Staff Software Engineer, Cluster: ML
# Job Title: Accounting Manager, OpEx, Cluster: ML
# Job Title: Patient Care Assistant I - Multiple openings, Cluster: ML
# Job Title: Respiratory Therapist Home Medical Equipment FT, Cluster: ML
# Job Title: Retail Store Tailor, Cluster: ML
# Job Title: Physical Therapist (PT) - $5,000.00 Sign On Bonus Available, Cluster: ML
# Job Title: Global Specialist, Cluster: ML
# Job Title: Senior Mechanical Engineer, Cluster: ML
# Job Title: Senior Manager, Global Distribution, Cluster: ML
# Job Title: Senior Manager Supply Chain Management, Cluster: ML
# Job Title: Fund Controller ( PE Accounting Focus), Cluster: ML
# Job Title: Site Reliability Engineer, Cluster: ML
# Job Title: Fleet Car Delivery Driver, Cluster: ML
# Job Title: Senior Software Engineer, Cluster: ML
# Job Title: General Manager, Cluster: ML
# Job Title: Nurse - RN - Med Surg Tele, Cluster: ML
# Job Title: Prestige Beauty Advisor, Cluster: ML
# Job Title: Shipping/Receiving Clerk, Cluster: ML
# Job Title: CT Technologist - Radiology, Cluster: ML
# Job Title: Manufacturing Planner/Scheduler II, Cluster: ML
# Job Title: Senior Manager, Technical Accounting, Cluster: ML
# Job Title: Market Development Manager - Hematology/Oncology, Cluster: ML
# Job Title: Housekeeping Clerk (Full-time), Cluster: ML
# Job Title: Area Leisure Sales Manager, Hawaii, Cluster: ML
# Job Title: Central Sterile Processing, Assoc., Cluster: ML
# Job Title: Construction Project Manager [5435], Cluster: ML
# Job Title: Temp - RN - Telemetry - Cardiac / Med Surg / Float (Days) Glens Falls, NY, Cluster: ML
# Job Title: RN - ER Overflow - *DAYS*, Cluster: ML
# Job Title: CWON Certified Wound Ostomy RN - Home Health, Cluster: ML
# Job Title: Physical Therapist (PT) - $10,000.00 Sign On Bonus Available, Cluster: ML
# Job Title: Senior SC Lead - Process Manufacturing (989357), Cluster: ML
# Job Title: Office Manager, Cluster: ML
# Job Title: Salesforce Developer, Cluster: ML
# Job Title: Entry-Level Mule IPC Engineer, Cluster: ML
# Job Title: Entry-level Mule Wiring Engineer, Cluster: ML
# Job Title: HR Manager, Cluster: ML
# Job Title: PROGRAM MANAGEMENT SPECIALIST, Cluster: ML
# Job Title: Faculty Instructor - Criminal Justice and Political Science Instructors, Cluster: ML
# Job Title: Global Supply & BI Analyst (FL, USA), Cluster: ML
# Job Title: Remote Culinary & Foodie Vacation Specialist, Cluster: ML
# Job Title: Software Engineer (Local to Michigan), Cluster: ML
# Job Title: Information Technology Project Manager, Cluster: ML
# Job Title: Network Engineer (Required Clearance), Cluster: ML
# Job Title: Quality Engineer, Cluster: ML
# Job Title: Security Service Mesh Engineer, Cluster: ML
# Job Title: Design Engineer (Aerospace), Cluster: ML
# Job Title: Lead Software Engineer, Cluster: ML
# Job Title: Cloud Engineer, Cluster: ML
# Job Title: Legal Assistant #36216, Cluster: ML
# Job Title: Cardiovascular Specialist, Cluster: ML
# Job Title: SAP PP Application Specialist - Contract to Hire, Cluster: ML
# Job Title: Executive Assistant, Cluster: ML
# Job Title: Account/Product Manager (Boston based), Cluster: ML
# Job Title: HCP Marketing Specialist, Cluster: ML
# Job Title: AP Data Entry Associate, Cluster: ML
# Job Title: OPERATIONS ASSISTANT MANAGER, Cluster: ML
# Job Title: Site Manager , Cluster: ML
# Job Title: MERCHANDISE ASSISTANT MANAGER, Cluster: ML
# Job Title: Business Owner, Cluster: ML
# Job Title: Business Development Associate, Cluster: ML
# Job Title: Clinical Research Coordinator, Cluster: ML
# Job Title: Lead Embedded Linux Engineer - Yocto , Cluster: ML
# Job Title: Project Manager, Cluster: ML
# Job Title: Foreign Service Regional Medical Officer, Cluster: ML
# Job Title: Sales Representative, Cluster: ML
# Job Title: Manufacturing Manager, Cluster: ML
# Job Title: CDL A Local Delivery Truck Driver, Cluster: ML
# Job Title: General Dentist - Full Time - Less than 60 Min from NYC!, Cluster: ML
# Job Title: Registered Nurse, Ambulatory OB/GYN (High Risk Nurse-GDM), 32 hours (Days), Cluster: ML
# Job Title: Dishwasher, Cluster: ML
# Job Title: Warehouse Associate, Cluster: ML
# Job Title: Local CDL A or CDL B Driver, Cluster: ML
# Job Title: Marketing Associate, Cluster: ML
# Job Title: Cultural Resources Technician, Cluster: ML
# Job Title: Senior Network Engineer, Cluster: ML
# Job Title: Senior Strategic Partner Manager, AI, Cluster: ML
# Job Title: Sales Representative - Morgantown/Wheeling/Weirton/Triadelphia, WV, Cluster: ML
# Job Title: Server Administrator, Cluster: ML
# Job Title: Corporate Accounting Manager, Treasury Accounting, Cluster: ML
# Job Title: Operations Professional 1, Cluster: ML
# Job Title: Construction Project Manager - Civil Concrete, Cluster: ML
# Job Title: Cook, Cluster: ML
# Job Title: Senior Software Engineer Test, Cluster: ML
# Job Title: Manager, Executive Visual Storytelling, Cluster: ML
# Job Title: CT Technologist, Cluster: ML
# Job Title: Surgery Scheduler, Cluster: ML
# Job Title: (US) Software Implementation Consultant - Level 2 - Financial, Cluster: ML
# Job Title: Machine Learning Engineer, Cluster: ML
# Job Title: Supplier Quality Engineer - Sensors, Cluster: ML
# Job Title: Engineering Director, Ubuntu Desktop, Cluster: ML
# Job Title: Room Service Server, Cluster: ML
# Job Title: Pool Server (Seasonal), Cluster: ML
# Job Title: Auto Body Technician, Cluster: ML
# Job Title: Public Service Assistant Specialist - Anthropology, Cluster: ML
# Job Title: Assistant Director, OCPD (Health Careers Team), Cluster: ML
# Job Title: Associate Scientist, QC, Cluster: ML
# Job Title: Volunteer: Castellow Hammock EcoAction Day (April 2024), Cluster: ML
# Job Title: Master Plumber, Cluster: ML
# Job Title: Information Security Director, Cluster: ML
# Job Title: Technical Project Manager, US, Cluster: ML
# Job Title: Resident Chef, Cluster: ML
# Job Title: Volunteer: Sociocracy Volunteer, Cluster: ML
# Job Title: Food Service Manager, Cluster: ML
# Job Title: Senior Business Systems Analyst, Cluster: ML
# Job Title: OIM Developer, Cluster: ML
# Job Title: Infotainment Developer, Cluster: ML
# Job Title: Industrial Hygiene Professional, Cluster: ML
# Job Title: Application Support Analyst, Cluster: ML
# Job Title: Senior Structural Engineer, Cluster: ML
# Job Title: Production Coordinator (Hrly), Cluster: ML
# Job Title: Legal Assistant (REMOTE), Cluster: ML
# Job Title: Special Education, P-12, Educational Interpreter - DHH - Special Education Rover, Cluster: ML
# Job Title: Healthcare Sales Trainee, Cluster: ML
# Job Title: Sr. Administrative Assistant, Cluster: ML
# Job Title: Registered Nurse - RN - LTAC, Cluster: ML
# Job Title: Part Time Licensed Talk Therapist, Cluster: ML
# Job Title: Registered Nursing- RN - Long Term Care/Skilled Nursing Facility, Cluster: ML
# Job Title: Physician Assistant, Cluster: ML
# Job Title: Registered Nursing- RN - Long Term Care/Skilled Nursing Facility, Cluster: ML
# Job Title: Travel/LOCAL CONTRACT - LTC Licensed Practical Nurse **up to 1,600/wk** (LPN), Cluster: ML
# Job Title: REGISTERED NURSE Med /Surg Unit, Cluster: ML
# Job Title: Account Executive, Cluster: ML
# Job Title: Commercial Sales Manager, Cluster: ML
# Job Title: Frontline Sales Consultant ($75,000-$200,000/yr), Cluster: ML
# Job Title: Med-Surg Registered Nurse, Cluster: ML
# Job Title: Handyperson, Cluster: ML
# Job Title: Med-Surg Registered Nurse, Cluster: ML
# Job Title: Telemetry Registered Nurse, Cluster: ML
# Job Title: Retail Sales and Store Support, Cluster: ML
# Job Title: Practice Development Manager(CoolSculpting) -Allergan Aesthetics-Tampa, FL, Cluster: ML
# Job Title: Dishwasher, Part-Time, Cluster: ML
# Job Title: Store Manager - Spencer's, Cluster: ML
# Job Title: Manager, Sales and Customer Service, Cluster: ML
# Job Title: Engineer II, Paramus Park - Full Time, Cluster: ML
# Job Title: Registered Nurse (RN) - Med Surg - $29-42 per hour - 1161353, Cluster: ML
# Job Title: Manager, Sales and Customer Service, Cluster: ML
# Job Title: Venue Director - Audio Visual, Event Technology - Hot Springs, VA, Cluster: ML
# Job Title: FIELD SERVICE POWER GENERATION TECHNICIAN, Cluster: ML
# Job Title: Intensivist - Tucson, AZ, Cluster: ML
# Job Title: Finance Manager, Corporate Finance, Cluster: ML
# Job Title: Patient Care Technician (PCT) - Step-Down Critical Care Unit PRN, Cluster: ML
# Job Title: Manager, Geospatial Data Analytics Program Development - Albuquerque (Onsite), Cluster: ML
# Job Title: Senior Sales Executive, Cluster: ML
# Job Title: Business Operations Director, Cluster: ML
# Job Title: UX Research Intern, Cluster: ML
# Job Title: RN- OLGMC 10W Observation- Full Time Days, Cluster: ML
# Job Title: Sales and Service Route Class B Driver *5K SIGN ON BONUS*, Cluster: ML
# Job Title: Lobby Greeter Concierge - Hilton Hawaiian Village Waikiki Beach, Cluster: ML
# Job Title: Field Service Technician I, Cluster: ML
# Job Title: Corinth Reman Large Engine Assembly Logistics II (1st shift), Cluster: ML
# Job Title: Cloud Engineer, Senior with Security Clearance, Cluster: ML
# Job Title: Seasonal Property Caretaker, Cluster: ML
# Job Title: Human Resources Orientation & Internship Program Manager, Cluster: ML
# Job Title: Shipping Clerk, Cluster: ML
# Job Title: Food Captain, Cluster: ML
# Job Title: Observability Engineer, Cluster: ML
# Job Title: Assistant General Counsel - Corporate and Securities, Cluster: ML
# Job Title: Marketing Manager, Cluster: ML
# Job Title: Financial Analyst, Cluster: ML
# Job Title: Production Supervisor - 2nd Shift, Cluster: ML
# Job Title: Night Auditor, Cluster: ML
# Job Title: Senior Accountant - 99% Remote - Growing Tech Org!, Cluster: ML
# Job Title: Social Media Representative, Cluster: ML
# Job Title: Maintenance Manager, Cluster: ML
# Job Title: Front Desk Agent, Cluster: ML
# Job Title: Financial Analyst, Cluster: ML
# Job Title: Copy of Construction Engineer Ill, Cluster: ML
# Job Title: RN Weekend Supervisor Sa/Su 6:45a-7:15p, Cluster: ML
# Job Title: Business Support Analyst Senior – Claims Workforce Planning, Cluster: ML
# Job Title: Keyholder - The Cosmetics Company Store - 20hrs - Florida Keys - Florida City, FL, Cluster: ML
# Job Title: Sales Representative, Cluster: ML
# Job Title: LVN - Nursing Float Pool - SRS North County - Days - FT, Cluster: ML
# Job Title: Project Manager (Construction), Cluster: ML
# Job Title: HVAC Sheet Metal Foreman, Cluster: ML
# Job Title: Rail E&P Electrician, Cluster: ML
# Job Title: Defense Analyst/Intelligence Analyst, Cluster: ML
# Job Title: Chief Credit Officer, Cluster: ML
# Job Title: Worker, Cluster: ML
# Job Title: Project Management Professional (PMP), Cluster: ML
# Job Title: Project Specialist, Cluster: ML
# Job Title: Product Owner/Business Analyst, Cluster: ML
# Job Title: Field Service Engineer - Los Angeles, Cluster: ML
# Job Title: Part Time - Fulfillment Associate - Flexible, Cluster: ML
# Job Title: Retail Sales – Part Time, Cluster: ML
# Job Title: LPN for 1:1 School Days, Cluster: ML
# Job Title: Quality Technician, Cluster: ML
# Job Title: LPN, Nurse Residency, Cluster: ML
# Job Title: One on One Care - Home Care - Nurse, Cluster: ML
# Job Title: Flow Inventory Associate, Cluster: ML
# Job Title: Veterinary Assistant, Cluster: ML
# Job Title: PHYSICAL THERAPY ASSISTANT (PTA) - WARREN HILLS NURSING AND REHABILITATION CENTER, Cluster: ML
# Job Title: CERTIFIED OCCUPATIONAL THERAPY ASSISTANT (COTA) - THREE RIVERS HEALTH AND REHABILITATION CENTER, Cluster: ML
# Job Title: CERTIFIED NURSING ASSISTANT - MARY GRAN, Cluster: ML
# Job Title: REGISTERED NURSE - OAK FOREST HEALTH & REHAB CENTER, Cluster: ML
# Job Title: Call Center Representative, Cluster: ML
# Job Title: Sales Manager, Cluster: ML
# Job Title: CERTIFIED NURSING ASSISTANT - WESTFIELD REHABILITATION AND HEALTH CENTER, Cluster: ML
# Job Title: HOSPICE REGISTERED NURSE, Cluster: ML
# Job Title: Purchasing Manager, Cluster: ML
# Job Title: OCCUPATIONAL THERAPIST (OT) - YADKIN NURSING CARE CENTER, Cluster: ML
# Job Title: Project Financial Analyst, Cluster: ML
# Job Title: REGISTERED NURSE - WOODLANDS NURSING AND REHABILITATION CENTER, Cluster: ML
# Job Title: CERTIFIED NURSING ASSISTANT - PISGAH MANOR, Cluster: ML
# Job Title: MEDICATION AIDE - ROXBORO HEALTHCARE & REHABILITATION CENTER, Cluster: ML
# Job Title: LICENSED PRACTICAL NURSE (LPN) - HIGHLAND HOUSE, Cluster: ML
# Job Title: HOSPICE REGISTERED NURSE, Cluster: ML
# Job Title: LICENSED PRACTICAL NURSE - BERMUDA COMMONS, Cluster: ML
# Job Title: CERTIFIED NURSING ASSISTANT - BERMUDA COMMONS, Cluster: ML
# Job Title: HOME CARE PHYSICAL THERAPIST (PT), Cluster: ML
# Job Title: Sales Manager, Cluster: ML
# Job Title: School Bus Driver, Cluster: ML
# Job Title: SUPPORT NURSE (LPN) - LOUISBURG HEALTH & REHAB CENTER, Cluster: ML
# Job Title: Accounting Administrative Assistant, Cluster: ML
# Job Title: Executive assistant, flex time offsite/local, Cluster: ML
# Job Title: Software Engineer III, Cluster: ML
# Job Title: Ecommerce Content Producer, Cluster: ML
# Job Title: Direct Sales, Cluster: ML
# Job Title: Full Time LPN- Pediatrics, Cluster: ML
# Job Title: Junior Associate Attorney, Cluster: ML
# Job Title: Immigration Paralegal, Cluster: ML
# Job Title: PHP Full Stack Developer, Cluster: ML
# Job Title: Program Manager, Cluster: ML
# Job Title: Dietitian, Cluster: ML
# Job Title: Senior Director of Finance or Controller, Cluster: ML
# Job Title: Member Relationship Specialist I, Cluster: ML
# Job Title: Miami OAE Tutor, Cluster: ML
# Job Title: Seasonal Grassland Steward, Cluster: ML
# Job Title: Entry Level Sales, Cluster: ML
# Job Title: Senior Mechanical Engineer, Cluster: ML
# Job Title: Controller, Cluster: ML
# Job Title: Market Research Intern, Cluster: ML
# Job Title: IT Salesforce Consultant, Cluster: ML
# Job Title: Sr  Manager, Digital Strategy and Issues Management, Cluster: ML
# Job Title: Sales Associate (Trauma) – Rapid City, SD – DePuy Synthes, Cluster: ML
# Job Title: Cancer Center of Acadiana - Patient Access Rep - Monday-Friday 7am to 4:30pm, Cluster: ML
# Job Title: Entry Level Chemist, Cluster: ML
# Job Title: Store Manager - Famous Footwear, Cluster: ML
# Job Title: Territory Manager Idaho/Montana, Cluster: ML
# Job Title: Construction Superintendent, Cluster: ML
# Job Title: Pharmacist, Cluster: ML
# Job Title: Part-Time Assistant Manager - Famous Footwear, Cluster: ML
# Job Title: Overnight Manager, Cluster: ML
# Job Title: .Net Developer, Cluster: ML
# Job Title: CPP-5.2, Practice Leader Navigator, Child Protection Unit, Mallee Area, Cluster: ML
# Job Title: Physical Therapist - Pembroke, MA, Cluster: ML
# Job Title: Public Area Attendant, Cluster: ML
# Job Title: Vice President, Product Marketing, Cluster: ML
# Job Title: Pipefitter Journeyman, Cluster: ML
# Job Title: Product Success Specialist (for product managers who want to guide other product teams), Cluster: ML
# Job Title: Peer Support Specialist I, Cluster: ML
# Job Title: Contracts Manager, Cluster: ML
# Job Title: Seasonal Merchandising Service Associate - Weekends Preferred, Cluster: ML
# Job Title: Contracts, Procurement and Supplier Diversity Intern (Fall 2024), Cluster: ML
# Job Title: Seasonal Merchandising Service Associate - Weekends Preferred, Cluster: ML
# Job Title: Merchandising Service Manager, Cluster: ML
# Job Title: Seasonal Merchandising Service Associate - Weekends Preferred, Cluster: ML
# Job Title: Purchasing Coordinator, Cluster: ML
# Job Title: Sales Associate / Key Sales / Seasonal Opportunities - Banter by Piercing Pagoda - Dartmouth Mall - Store 150 - Dartmouth, MA, Cluster: ML
# Job Title: Non OHSU Student Worker, Cluster: ML
# Job Title: Sr. Director of Indirect and IT Procurement, Cluster: ML
# Job Title: Retail Supervisor, Full Time, Merchandising - Atlantic Station, Cluster: ML
# Job Title: Account Executive, Corporate Sales, Cluster: ML
# Job Title: Administrative Specialist II, Cluster: ML
# Job Title: Recreation Director for Long Term Care Facility, Cluster: ML
# Job Title: Insurance Services Specialist, Cluster: ML
# Job Title: Permanent Staff Operating Room RN job in High Point, NC - Make $32 to $48/hour, Cluster: ML
# Job Title: Travel - PCU - Nurse Job - $2,791/wk - $2,980/wk, Cluster: ML
# Job Title: Insurance Agent (base + uncapped commissions, $5K licensed bonus), Cluster: ML
# Job Title: Patient Access Representative, Scheduling - Full time, Cluster: ML
# Job Title: Travel - PCU - Nurse Job - $2,296/wk - $2,486/wk, Cluster: ML
# Job Title: Store Associate, PTU - Lehi, Cluster: ML
# Job Title: Manager, People Services (PSM), Cluster: ML
# Job Title: Travel - Med Surg - Nurse Job - $2,105/wk - $2,295/wk, Cluster: ML
# Job Title: Early Careers: Intern Conversion Only: Health and Benefits (US) – Health Immersion Program (HIP) Analyst - East - 2024, Cluster: ML
# Job Title: Senior Distributed Systems Engineer, AI Infrastructure, Cluster: ML
# Job Title: Corporate Security Officer, Cluster: ML
# Job Title: Sales Manager-Atlanta, GA, Cluster: ML
# Job Title: Medical Assistant, Cluster: ML
# Job Title: National Account Manager, Cluster: ML
# Job Title: Sales Specialist, Cluster: ML
# Job Title: Summer Intern, Cluster: ML
# Job Title: Cash Application Analyst – Washington DC, Cluster: ML
# Job Title: Echo/Vascular Tech I, Cluster: ML
# Job Title: Associate Director, Finance and Controlling, Cluster: ML
# Job Title: Medical Assistant Bariatrics Denver Midtown, Cluster: ML
# Job Title: UKG Dimensions Timekeeping Consultant, Cluster: ML
# Job Title: Certified Pharmacy Technician, Cluster: ML
# Job Title: Primary Care Provider for Community Clinic - APP or MD/DO, Cluster: ML
# Job Title: Records Manager, Cluster: ML
# Job Title: Sales Manager, Cluster: ML
# Job Title: Sales Manager, Cluster: ML
# Job Title: Sales Manager, Cluster: ML
# Job Title: Senior Retail Sales Associate (Full-Time), Cluster: ML
# Job Title: Senior Designer, Cluster: ML
# Job Title: Front Desk Associate, Cluster: ML
# Job Title: Registered Nurse, Cluster: ML
# Job Title: Sales Manager, Cluster: ML
# Job Title: Bilingual Licensed Health Insurance Agent, Cluster: ML
# Job Title: Assistant Stylist, Cluster: ML
# Job Title: Director of Nursing, Cluster: ML
# Job Title: Delivery Driver - Local Area, Cluster: ML
# Job Title: Solutions Architect, Cluster: ML
# Job Title: Emergency Room Registered Nurse, Cluster: ML
# Job Title: Data Scientist Intern, Cluster: ML
# Job Title: Customer Service Representative, Physician Practice, Cluster: ML
# Job Title: Dentist - SCI Coal Township, Cluster: ML
# Job Title: Lead Propane CDL Delivery Driver, Cluster: ML
# Job Title: Account Executive *REMOTE*, Cluster: ML
# Job Title: Senior Systems Software Engineer-REMOTE, Cluster: ML
# Job Title: Department Coordinator III - LEAD Department - College of Education and Human Development, Cluster: ML
# Job Title: Project Specialist I, Cluster: ML
# Job Title: Program Manager - Systems Engineering, Integration, & Test with Security Clearance, Cluster: ML
# Job Title: Cleared Security Officer - DOD Site with Security Clearance, Cluster: ML
# Job Title: Solar Engineer, Sr. Analyst, Cluster: ML
# Job Title: Remote Observation Assistant, Cluster: ML
# Job Title: Customer Service (Remote), Cluster: ML
# Job Title: Operations Assistant, Cluster: ML
# Job Title: Registered Nurse - 1761700, Cluster: ML
# Job Title: CUA 2 Educational Liaison, Cluster: ML
# Job Title: Apprentice Jeweler - Signet Jewelers - Frisco Village - Frisco, TX, Cluster: ML
# Job Title: Quality Assurance Inspector, Cluster: ML
# Job Title: Fixed Maintenance, Cluster: ML
# Job Title: Registered Nurse Case Manager- Hospice, Cluster: ML
# Job Title: Creative Executive Chef  Farm to Table, Cluster: ML
# Job Title: (USA) Personal Shopper - Sam's, Cluster: ML
# Job Title: (USA) Bakery Lead, Cluster: ML
# Job Title: Software Engineering Manager - XR Cameras & Sensors, Cluster: ML
# Job Title: (USA) Merchandising Lead, Cluster: ML
# Job Title: Executive Mixed Reality Producer, Entertainment Experiences, Cluster: ML
# Job Title: Associate General Counsel, Product (Youth), Cluster: ML
# Job Title: Salesperson, Cluster: ML
# Job Title: Front Desk Assistant, Cluster: ML
# Job Title: Clinician III, Cluster: ML
# Job Title: Software Build - Release Engineer, Cluster: ML
# Job Title: Store Hourly, Cluster: ML
# Job Title: Sales Representative, Cluster: ML
# Job Title: HVAC Technician, Cluster: ML
# Job Title: Administrative Assistant, Cluster: ML
# Job Title: Mental Health Therapist (IIC-in person only), Cluster: ML
# Job Title: Dynamics Business Central Finance Consultant, Cluster: ML
# Job Title: Interiors Superintendent, Cluster: ML
# Job Title: Coil Shop Operative, Cluster: ML
# Job Title: Registered Dental Hygienist, Cluster: ML
# Job Title: Turnaround/Outage Maintenance Manager, Cluster: ML
# Job Title: German Speaking BDR / SDR, Cluster: ML
# Job Title: General Engineer, Cluster: ML
# Job Title: Sales Manager, Cluster: ML
# Job Title: Intellectual Property Attorney, Cluster: ML
# Job Title: Outside Plant Engineer, Seattle, WA, Cluster: ML
# Job Title: CERTIFIED NURSING ASSISTANT - CNA - BRADLEY CREEK HEALTH CENTER, Cluster: ML
# Job Title: Production Manager, Direct Mail, Cluster: ML
# Job Title: REGISTERED NURSE - WOODHAVEN, Cluster: ML
# Job Title: KV Van Driver, Cluster: ML
# Job Title: OCCUPATIONAL THERAPIST (OT) - ELIZABETHTOWN HEALTHCARE & REHAB CENTER, Cluster: ML
# Job Title: HOSPICE REGISTERED NURSE, Cluster: ML
# Job Title: Assistant Property Manager, Cluster: ML
# Job Title: SUPPORT NURSE (LPN) - LOUISBURG HEALTH & REHAB CENTER, Cluster: ML
# Job Title: Surveillance Investigator, Cluster: ML
# Job Title: RESPIRATORY THERAPIST - OAK FOREST HEALTH & REHAB CENTER, Cluster: ML
# Job Title: HOSPICE REGISTERED NURSE, Cluster: ML
# Job Title: Application Support Engineer, Cluster: ML
# Job Title: Full Line Sales Specialist, Cluster: ML
# Job Title: CERTIFIED NURSING ASSISTANT - BRADLEY CREEK HEALTH CENTER, Cluster: ML
# Job Title: LICENSED PRACTICAL NURSE - PARKVIEW HEALTH AND REHABILITATION CENTER, Cluster: ML
# Job Title: Information Technology Security Analyst, Cluster: ML
# Job Title: Coaching Vacancies (Modesto High School) Open to Modesto City Schools Permanent and Probationary Certificated Employees Only, Cluster: ML
# Job Title: Full Line Sales Specialist, Cluster: ML
# Job Title: Customer Service Representative, Cluster: ML
# Job Title: Account Manager, Immunology - Phoenix - South, AZ, Cluster: ML
# Job Title: Financial Controller, Cluster: ML
# Job Title: Accountant, Cluster: ML
# Job Title: Payroll Operations Manager US & CANADA, Cluster: ML
# Job Title: IMMEDIATE HIRE: Entry Level Sales & Marketing, Cluster: ML
# Job Title: Warehouse/Production Assistant, Cluster: ML
# Job Title: ERP Project Manager, Cluster: ML
# Job Title: Head of Growth, Cluster: ML
# Job Title: Physical Therapist – Physical Therapy DHOC, Cluster: ML
# Job Title: Sales Analyst, Cluster: ML
# Job Title: Assistant Professor of Business Analytics, Cluster: ML
# Job Title: Senior SAP BW/4HANA Developer, Cluster: ML
# Job Title: Production and Graphics Manager, Cluster: ML
# Job Title: Senior Software Engineer, Cluster: ML
# Job Title: Drupal Developer  || W2 Only, Cluster: ML
# Job Title: Principal Software Engineer, Large Platform, Cluster: ML
# Job Title: 7th Grade Social Studies Teacher - Middle School, Cluster: ML
# Job Title: Senior Outlet Merchandise Manager, Cluster: ML
# Job Title: Business Development Manager - IT Consulting, Cluster: ML
# Job Title: Building Inspector/Plans Examiner III, Cluster: ML
# Job Title: Artificial Intelligence Engineer, Cluster: ML
# Job Title: School Aide/Paraprofessional/ Student Assistant (Soaring Heights School), Cluster: ML
# Job Title: Senior Vice President, Group Account Director, Cluster: ML
# Job Title: Adobe Campaign Classic Developer, Cluster: ML
# Job Title: Science/Social Studies Teacher (4th Grade), Cluster: ML
# Job Title: Litigation Attorney, Cluster: ML
# Job Title: Account Executive, Cluster: ML
# Job Title: Lead Development Representative , Cluster: ML
# Job Title: Merchandiser, Cluster: ML
# Job Title: Mechanical Design Engineer, Cluster: ML
# Job Title: Product Development Engineer, Cluster: ML
# Job Title: Special Education Music Therapist, Cluster: ML
# Job Title: Contracts Specialist, Cluster: ML
# Job Title: Data Architect, Cluster: ML
# Job Title: Feeder Catcher, Cluster: ML
# Job Title: Sr Program Manager, Cluster: ML
# Job Title: Electrical Engineer, Cluster: ML
# Job Title: Associate Director, Corporate Communications, Cluster: ML
# Job Title: Quality Control Inspection Lead, Cluster: ML
# Job Title: Assistant Property Manager, Cluster: ML
# Job Title: Structural Engineer -  BUILDER - SMS, Cluster: ML
# Job Title: Caregiver, Cluster: ML
# Job Title: Registered Nurse (RN) Southern Maine!!, Cluster: ML
# Job Title: Instructional Designer, Cluster: ML
# Job Title: Commissions Admin, Cluster: ML
# Job Title: Technical Support Specialist, Cluster: ML
# Job Title: Financial Services Professional, Cluster: ML
# Job Title: Accounting Manager, Cluster: ML
# Job Title: Inside Sales Representative, Cluster: ML
# Job Title: Corporate Actions IC Associate (Stock Dividends), Cluster: ML
# Job Title: SQL Developer, Cluster: ML
# Job Title: Solar Project Manager, Construction, Cluster: ML
# Job Title: Experience Team Member, Cluster: ML
# Job Title: Insurance product senior manager, Cluster: ML
# Job Title: Technical Scrum Master, Cluster: ML
# Job Title: Packaging Engineer, Cluster: ML
# Job Title: Physician Practice RN- Orthopedics & Sports Medicine, Cluster: ML
# Job Title: Auto Physical Damage Desk Appraiser, Cluster: ML
# Job Title: Wellness Rehabilitation Specialist - Part-Time/Wage, Cluster: ML
# Job Title: Catering Lead, Cluster: ML
# Job Title: Salesperson, Cluster: ML
# Job Title: Director of Advancement, Cluster: ML
# Job Title: Named Account Manager, Cluster: ML
# Job Title: INTERDISCIPLINARY TECHNICAL EXPERT ELECTRONICS ENGINEER/COMPUTER SCIENTIST, Cluster: ML
# Job Title: Segment Quality Lead, Cluster: ML
# Job Title: Weapon System Operations Analyst, Cluster: ML
# Job Title: Design Engineer, Cluster: ML
# Job Title: Senior Analyst, Precision, Cluster: ML
# Job Title: Corporate Event Coordinator, Cluster: ML
# Job Title: Customer Service Representative-Temporary/Seasonal, Cluster: ML
# Job Title: Maintenance Technician, Cluster: ML
# Job Title: Industrial Maintenance Electrician, Cluster: ML
# Job Title: Junior Groomer, Cluster: ML
# Job Title: Animal Care Supervisor, Cluster: ML
# Job Title: In-Vitro Assay/Microbiology Technician, Cluster: ML
# Job Title: Vice President of Finance - Gulf Winds Credit Union , Cluster: ML
# Job Title: Independent Distributor and sales rep, Cluster: ML
# Job Title: Healthcare Project Manager, Cluster: ML
# Job Title: 지역 영업 관리자, Cluster: ML
# Job Title: Interior Designer, Entry-Level, Cluster: ML
# Job Title: Assistant Controller, Cluster: ML
# Job Title: Mid Level .NET Core Backend Developer - Government Experience, Cluster: ML
# Job Title: Lead Case Manager, Cluster: ML
# Job Title: ESG Lawyer, Cluster: ML
# Job Title: Psychology Postdoctoral Fellow $85,000 , Cluster: ML
# Job Title: FE/Fullstack Software Engineer, Cluster: ML
# Job Title: Product Analyst, Cluster: ML
# Job Title: Beautyscope - SDS Role, Cluster: ML
# Job Title: Payroll Administrator (140528), Cluster: ML
# Job Title: MD/AUTO FIELD CLAIMS REPRESENTATIVE I, II, SR., Cluster: ML
# Job Title: Service Technician, Cluster: ML
# Job Title: Associate Graphic Design Intern, Cluster: ML
# Job Title: Service Technician, Cluster: ML
# Job Title: Distribution Center Loader, Cluster: ML
# Job Title: Inside Sales Specialist, Cluster: ML
# Job Title: Compressed Air System, IoT Field Engineer, Cluster: ML
# Job Title: Wind Technician III - Rankin, TX, Cluster: ML
# Job Title: Custodian, Cluster: ML
# Job Title: Driver - CDL (B), Cluster: ML
# Job Title: Fireproofing Project Manager- Carlsbad, CA, Cluster: ML
# Job Title: Senior Power System Protection and Control Engineer, Cluster: ML
# Job Title: Vetco Veterinary Clinic Advisor - Training Provided (Driving Role), Cluster: ML
# Job Title: Grooming Salon Manager, Cluster: ML
# Job Title: Receptionist, Cluster: ML
# Job Title: Detention Officer, Cluster: ML
# Job Title: Housekeeping Manager, Cluster: ML
# Job Title: Warehouse Specialist, Cluster: ML
# Job Title: Senior Data Analyst - Ecommerce & Marketing, Cluster: ML
# Job Title: PA or CRNP, Center for Diabetes & Endocrinology, Cluster: ML
# Job Title: Cell Packer, Cluster: ML
# Job Title: Electro-Mechanical Technician Senior, Cluster: ML
# Job Title: Systems Analyst, Cluster: ML
# Job Title: Triage Nurse, Cluster: ML
# Job Title: Salesforce Solution Architect, Cluster: ML
# Job Title: Receptionist, Cluster: ML
# Job Title: GC Retail Instructor Store 615, Cluster: ML
# Job Title: Case Manager RN - PAMC Case Mgmt, Cluster: ML
# Job Title: Local CDL A Truck Driver Job (Phila, PA), Cluster: ML
# Job Title: Used Car Sales Manager, Cluster: ML
# Job Title: Retail Assistant Store Manager (Part Time) - Island Walk, Cluster: ML
# Job Title: Senior Media Buyer, Cluster: ML
# Job Title: HR & Legal IT Delivery Leader,, Cluster: ML
# Job Title: Travel Nurse RN - Med/Surg in Beaufort, SC - Excellent Benefits 2024-04-11, Cluster: ML
# Job Title: SAP FICO Consultant, Cluster: ML
# Job Title: Travel Nurse RN - PCU - $1,792 per week in Murfreesboro, TN, Cluster: ML
# Job Title: Travel Nurse RN - ICU/Critical Care - $1,923 to $2,119 per week in Greenville, NC, Cluster: ML
# Job Title: Python Developer, Cluster: ML
# Job Title: Facilities Tech 3 - Night Shift, Cluster: ML
# Job Title: Nursing Educator, Cluster: ML
# Job Title: Truck Technician, Cluster: ML
# Job Title: Entry Level Oracle Financial Technology Consultant, Cluster: ML
# Job Title: Manager Designate, Cluster: ML
# Job Title: Senior Associate, Clearloop Commercial Partnerships, Cluster: ML
# Job Title: Environmental Field Scientist – Asbestos, Lead, Mold and Industrial Hygiene, Cluster: ML
# Job Title: Registered Nurse, PRN, Med Surg, Dillon, Cluster: ML
# Job Title: Retail Sales Specialist - $18.00 per hour, plus commission and incentives!, Cluster: ML
# Job Title: Estate Administrator, Cluster: ML
# Job Title: Info Security Analyst Entry Level - Vulnerability Assessment, Cluster: ML
# Job Title: OSP Fiber Residential ISP Technicians, Cluster: ML
# Job Title: HVAC Service Manager - Relocation Available, Cluster: ML
# Job Title: Transportation Program Specialist/ Transportation Data Analyst, Cluster: ML
# Job Title: Accounting Manager, Cluster: ML
# Job Title: System Engineer (Cryptography), Cluster: ML
# Job Title: Quality Inspector, Cluster: ML
# Job Title: Receiving Assistant, Cluster: ML
# Job Title: Delivery Truck Driver - CDL, Cluster: ML
# Job Title: Customer Success Manager- North America, Cluster: ML
# Job Title: Field Technician, Cluster: ML
# Job Title: Program Coordinator, Outreach, Cluster: ML
# Job Title: Equipment Project Manager, Cluster: ML
# Job Title: Senior Facilities Maintenance Tech, Cluster: ML
# Job Title: Primary Integrated Care (PIC) Care Coordinator, Cluster: ML
# Job Title: Associate Attorney, Cluster: ML
# Job Title: Retirement Specialist, Cluster: ML
# Job Title: Farm General Manager, Cluster: ML
# Job Title: Software Developer, Cluster: ML
# Job Title: Manager, Product Management, Card Fraud, Cluster: ML
# Job Title: DEVOPS BIG DATA AWS ENGINEER, Cluster: ML
# Job Title: Cardio Diag Technician I - Full Time Days, Cluster: ML
# Job Title: Marketing / Executive Assistant, Cluster: ML
# Job Title: Manager, Process Management, Cluster: ML
# Job Title: Registered Dietitian (RD) ( Must be a Registered Dietitian) $10,000 Sign on Bonus, Cluster: ML
# Job Title: Licensed Practical Nurse (LPN), Cluster: ML
# Job Title: Registered Nurse (RN), Cluster: ML
# Job Title: Engineering Technician - MicroStation/ORD, Cluster: ML
# Job Title: Quality Control Inspector, Cluster: ML
# Job Title: Machinist II, Cluster: ML
# Job Title: Sales Representative, Biopharma #26416, Cluster: ML
# Job Title: Operator Batcher 1, Cluster: ML
# Job Title: Maintenance Technician, Cluster: ML
# Job Title: Supervisor, LM Operations, Cluster: ML
# Job Title: Senior Software Developer, Cluster: ML
# Job Title: Project Manager, Cluster: ML
# Job Title: OSP Tech-Level II-Kansas City, Cluster: ML
# Job Title: Assignment Editor, WGBA, Cluster: ML
# Job Title: Newborn Hearing Screen Technician, Cluster: ML
# Job Title: Senior Coordinator, Talent Acquisition & Development, Cluster: ML
# Job Title: Senior Software Engineer, Full Stack (Java, AWS), Cluster: ML
# Job Title: Registered Physical Therapist, RPT, Cluster: ML
# Job Title: Senior Software Engineer, Back End (Python), Cluster: ML
# Job Title: Registered Nurse, Infection Prevention, Cluster: ML
# Job Title: Task Associate, Cluster: ML
# Job Title: Assembler, Cluster: ML
# Job Title: Speech Pathologist (Acute), Cluster: ML
# Job Title: Front Office Controller, Full Time, Great Benefits , Cluster: ML
# Job Title: Prestige Beauty Advisor, Cluster: ML
# Job Title: Guest Services Attendant, Cluster: ML
# Job Title: Junior Database Administrator, Cluster: ML
# Job Title: Billing Resolution Analyst II, Cluster: ML
# Job Title: Service Now Developer, Cluster: ML
# Job Title: Full Stack Swift with MYSQL, Cluster: ML
# Job Title: Executive Assistant, Cluster: ML
# Job Title: Administrative Project Manager, Medical Devices, Cluster: ML
# Job Title: Physician Assistant, Per Diem - Internal Medicine, Cluster: ML
# Job Title: Teller - Bilingual - Part Time, Cluster: ML
# Job Title: Operating Engineer, Cluster: ML
# Job Title: Claims Administrative Support Specialist, Cluster: ML
# Job Title: Customer Experience Lead - Glendale Galleria, Cluster: ML
# Job Title: Customer Experience Supervisor, Cluster: ML
# Job Title: Manager, Statistical Programming, Cluster: ML
# Job Title: Sprinkler Service Technician, Cluster: ML
# Job Title: RN-Cardiac Telemetry PCU, Cluster: ML
# Job Title: MGH-Assembler, Cluster: ML
# Job Title: Database Support Engineer, Cluster: ML
# Job Title: EXPERIENCED DEALER- TABLE GAMES, Cluster: ML
# Job Title: Credentialed Background Investigator, Cluster: ML
# Job Title: Senior Enterprise Architect, Cluster: ML
# Job Title: Data infrastructure engineer, Cluster: ML
# Job Title: Data Engineer General, Cluster: ML
# Job Title: Engagement VP - Real World Data, Cluster: ML
# Job Title: Financial Accountant, Cluster: ML
# Job Title: Senior Product Owner - Digital Benefits Experience, Cluster: ML
# Job Title: Entry Level Accounting Role, Cluster: ML
# Job Title: Anesthesiology CRNA - $210,000/yearly - $210,001/yearly, Cluster: ML
# Job Title: Psychiatric-Mental Health Physician - $312,000/yearly, Cluster: ML
# Job Title: Accounting Assistant, Cluster: ML
# Job Title: Director of Finance, Cluster: ML
# Job Title: Anesthesiology CRNA - $300,000/yearly - $350,000/yearly, Cluster: ML
# Job Title: CT Travel CT Technologist - Job Id: JO03718164, Cluster: ML
# Job Title: Mechanical Engineer, Junior, Cluster: ML
# Job Title: Director, Talent Development, Cluster: ML
# Job Title: Data Scientist Lead – Telematics (Remote), Cluster: ML
# Job Title: System Director Accounts Payable Service Delivery, Cluster: ML
# Job Title: Marketing Operations Manager, Cluster: ML
# Job Title: Line Cook, Cluster: ML
# Job Title: Bartender, Cluster: ML
# Job Title: Assistant Manager, Cluster: ML
# Job Title: Business Analytics Associate, Cluster: ML
# Job Title: Physical Therapist Assistant - PRN | Clear Lake North, Cluster: ML
# Job Title: Sample Clerk, Cluster: ML
# Job Title: Part Time Retail Merchandiser - Brandon FL 33511, Cluster: ML
# Job Title: Manager Transfer Products Pharma (Hybrid), Cluster: ML
# Job Title: Enforcement Officer, Cluster: ML
# Job Title: Account Executive - Pest, Cluster: ML
# Job Title: Cash Application Analyst – Washington DC, Cluster: ML
# Job Title: National Account Manager, Cluster: ML
# Job Title: National Account Manager, Cluster: ML
# Job Title: Machine Learning Engineer, Cluster: ML
# Job Title: No C2C - Senior Project Manager, Cluster: ML
# Job Title: Financial Contract Analyst – Overland Park KS, Cluster: ML
# Job Title: Principal Product Manager, Cluster: ML
# Job Title: Regional Learning Manager-Dallas TX, Cluster: ML
# Job Title: Live In LPN, Cluster: ML
# Job Title: 2024 Commercial Credit Underwriting Analyst Program – Cleveland, Cluster: ML
# Job Title: Outside Sales Representative, Cluster: ML
# Job Title: Travel SLP - $1,680 per week in Roseburg, OR, Cluster: ML
# Job Title: Controller, Cluster: ML
# Job Title: Construction Estimator, Cluster: ML
# Job Title: Visitor Services Supervisor, Cluster: ML
# Job Title: Executive Underwriter - Chubb Global Casualty, Cluster: ML
# Job Title: Consulting System Engineer, Cluster: ML
# Job Title: Customer Success Operations Senior Associate, Cluster: ML
# Job Title: Administrative Associate, Cluster: ML
# Job Title: AVP, Underwriting Team Leader - Multinational, Cluster: ML
# Job Title: Senior Industrial Security Representative (FSO), Cluster: ML
# Job Title: Senior Accounting Policy Accountant, Cluster: ML
# Job Title: Contract Project Manager, Cluster: ML
# Job Title: Senior Premium Audit Specialist | Remote, Cluster: ML
# Job Title: Client Manager, Cluster: ML
# Job Title: Field Support Specialist (42046), Cluster: ML
# Job Title: Lobby Receptionist (42027), Cluster: ML
# Job Title: Patient Service Representative - Call Center, Cluster: ML
# Job Title: Billing Analyst, Cluster: ML
# Job Title: AUTOMOTIVE TECHNICIAN, Cluster: ML
# Job Title: Sr. Process Engineer (On Site), Cluster: ML
# Job Title: Sr. Project Manager - Industrial Interiors, Cluster: ML
# Job Title: Clerical Assistant, Cluster: ML
# Job Title: PR Consultant (Hispanic Market Specialist), Cluster: ML
# Job Title: Systems Administrator, Cluster: ML
# Job Title: Change Management Specialist/Configuration Management(Teamcenter), Cluster: ML
# Job Title: School Based Site Coordinator, Cluster: ML
# Job Title: Associate Attorney, Cluster: ML
# Job Title: Storage Engineer, Cluster: ML
# Job Title: Physical Therapist, Cluster: ML
# Job Title: Accounting Specialist, Cluster: ML
# Job Title: Req:: IT Security Analyst _ Richmond, VA (Hybrid) _ W2 Only, Cluster: ML
# Job Title: Data Architect Onsite/Somerville, MA, Cluster: ML
# Job Title: Production Planner, Cluster: ML
# Job Title: Utility Inspector II, Cluster: ML
# Job Title: Research Program Manager, Cluster: ML
# Job Title: Service Coordinator, Residential Rehabilitation, Monday-Friday 8am - 4pm - Westminster, MD, Cluster: ML
# Job Title: Administrative Assistant, Cluster: ML
# Job Title: Customer Service Representative/Store Associate, Cluster: ML
# Job Title: DELIVERY ASSISTANT, Cluster: ML
# Job Title: Production Manager, Cluster: ML
# Job Title: Director of Operations, Cluster: ML
# Job Title: Chat support, Cluster: ML
# Job Title: Operations Manager II ( Nights), Cluster: ML
# Job Title: Oracle E- Business Suites Technical Consultant, Cluster: ML
# Job Title: Support Lead Part Time, Cluster: ML
# Job Title: District Manager - CT, Cluster: ML
# Job Title: Sales Associate Part Time - TOMMY HILFIGER, Cluster: ML
# Job Title: Structural Work Packager, Cluster: ML
# Job Title: Brand Ambassador, Mandarin-speaker, Cluster: ML
# Job Title: Senior FPGA Engineer, Cluster: ML
# Job Title: Guest Services Specialist, Cluster: ML
# Job Title: CT Technologist, Cluster: ML
# Job Title: Electrical Engineering Manager, Cluster: ML
# Job Title: Dry Goods Seasonal Associate, Cluster: ML
# Job Title: Designer, Cluster: ML
# Job Title: Managing Director of Research & Evaluation, Cluster: ML
# Job Title: Research Project Manager, Cluster: ML
# Job Title: Senior Epic Project Manager, Cluster: ML
# Job Title: Senior Service Oriented Architect - SOA (On-Site), Cluster: ML
# Job Title: Oracle PL/SQL Developer, Cluster: ML
# Job Title: Process Analyst, Cluster: ML
# Job Title: Entry Level Procurement Analyst, Cluster: ML
# Job Title: Experienced Payload Engineer, Cluster: ML
# Job Title: Sales Development Advisor (052824), Cluster: ML
# Job Title: Delivery Specialist, Cluster: ML
# Job Title: Mid-Level Procurement Analyst, Cluster: ML
# Job Title: Developmental Disabilities Secure Care Treatment Aide 1/Trainee (DDSCTA) (NY HELPS), Cluster: ML
# Job Title: Infrastructure Engineer, Cluster: ML
# Job Title: Registered Nurse 1 (NY HELPS), Cluster: ML
# Job Title: Business Development Representative, Cluster: ML
# Job Title: Workday Developer & Integrations Specialist, Cluster: ML
# Job Title: Construction Engineer, Cluster: ML
# Job Title: Sales Lead, Cluster: ML
# Job Title: Game Programmer (UEFN - Verse), Cluster: ML
# Job Title: FT Computed Tomography (CT) Tech *Up to $80,000 annually*, Cluster: ML
# Job Title: Sales Operations Analyst, Cluster: ML
# Job Title: Substitute Teacher - K-12 - Hiring Now, Cluster: ML
# Job Title: Research Finance Administrator II, Cluster: ML
# Job Title: Document Reviewer, Cluster: ML
# Job Title: Business Development Manager, Cluster: ML
# Job Title: Special Education Elementary Teacher, Cluster: ML
# Job Title: Account Specialist-Service, Cluster: ML
# Job Title: Seasonal Guest Services Pool Attendant, Cluster: ML
# Job Title: ECM Clinical Manager, Cluster: ML
# Job Title: Driver/Operator, Cluster: ML
# Job Title: Immigration Specialist, Cluster: ML
# Job Title: PCU/Step-down Nurse, Cluster: ML
# Job Title: Deli Associate, Cluster: ML
# Job Title: Registered Nurse Supervisor - RN - Long Term Care/Skilled Nursing Facility, Cluster: ML
# Job Title: Registered Nurse - RN - LTAC, Cluster: ML
# Job Title: Department Manager Starbucks - Glendale, AZ - 2821, Cluster: ML
# Job Title: Designer, Cluster: ML
# Job Title: Junior Illustrator, Cluster: ML
# Job Title: Registered Nurse - RN - ER (Emergency Room), Cluster: ML
# Job Title: Barista, Cluster: ML
# Job Title: Auto Body Technician, Cluster: ML
# Job Title: Orthodontic Assistant, Cluster: ML
# Job Title: Project Manager, Cluster: ML
# Job Title: Retail Sales Associate, Metro Center - Part Time, Cluster: ML
# Job Title: Radiology Tech Assistant, FT - Sun View, Cluster: ML
# Job Title: Lead Engineer, Structural, Cluster: ML
# Job Title: Intern - Operations, Cluster: ML
# Job Title: Community Turn Assistant (Temporary), Cluster: ML
# Job Title: Volunteer: Courses Coordinator Assistant, Cluster: ML
# Job Title: Sales Lead, Cluster: ML
# Job Title: Volunteer: Help a disabled Person with lawn care in Toledo, OH, Cluster: ML
# Job Title: Prep Cook (Main Kitchen) - Waldorf Astoria Beverly Hills, Cluster: ML
# Job Title: Medical Legal Regulatory Coordinator (Remote) - 24-127, Cluster: ML
# Job Title: Nurse Practitioner - Hospital Medicine PRN, Cluster: ML
# Job Title: Buyer I #: 24-02541, Cluster: ML
# Job Title: Senior Business Development Manager – Contracted Solutions Strategy, Cluster: ML
# Job Title: Senior Staff Accountant #: 24-02538, Cluster: ML
# Job Title: Sterile Processing Tech II, Cluster: ML
# Job Title: Kanoelani Elementray School, Grade K-2, Special Education Position (2024-00765), Cluster: ML
# Job Title: Locum | Physician Psychiatry, Cluster: ML
# Job Title: Commercial Underwriting Program in Detroit, Cluster: ML
# Job Title: DSCo OE Service Quality Coordinator, Cluster: ML
# Job Title: Associate Sales Consultant, Cluster: ML
# Job Title: Strategic Client Solutions Director, Cluster: ML
# Job Title: Implementation Manager, Cluster: ML
# Job Title: Locum | Physician Psychiatry, Cluster: ML
# Job Title: Business Development Manager - Utility Billing Software - Remote, Cluster: ML
# Job Title: Senior Manager SEC Reporting, Cluster: ML
# Job Title: Merchandiser, Cluster: ML
# Job Title: Electro-Mechanical Technician, Cluster: ML
# Job Title: Physical Therapist (SIGN ON BONUS) - New Haven, CT, Cluster: ML
# Job Title: Sr. Manager, Market Insights, Cluster: ML
# Job Title: ACAS Engineer, Cluster: ML
# Job Title: Software Engineer I, Cluster: ML
# Job Title: Sr. Ruby on Rails Engineer (Knowledge), Cluster: ML
# Job Title: Digital Forensics and Incident Response (DFIR) Intern, Cluster: ML
# Job Title: Part Time - Head Cashier - Flexible, Cluster: ML
# Job Title: Associate Veterinarian, Cluster: ML
# Job Title: Account Executive, Cluster: ML
# Job Title: Seasonal Merchandising Service Associate - Weekends Preferred, Cluster: ML
# Job Title: Retail Sales Associate (Part-Time), Cluster: ML
# Job Title: SUPERVISOR - CAGE, Cluster: ML
# Job Title: Account Executive, Cluster: ML
# Job Title: Bilingual Clinician - JOR, Cluster: ML
# Job Title: Sales Account Manager, Cluster: ML
# Job Title: Client Relationship Consultant II- Murray Scholls, Cluster: ML
# Job Title: salesperson, Cluster: ML
# Job Title: Line Cook (Part-Time), Cluster: ML
# Job Title: retail parts pro, Cluster: ML
# Job Title: Retail Sales Associate, Cluster: ML
# Job Title: Estimator, Cluster: ML
# Job Title: Store Driver, Cluster: ML
# Job Title: Auto Detailer, Cluster: ML
# Job Title: Servicing QC Auditor, Cluster: ML
# Job Title: (CNA) Certified Nursing Assistant, Cluster: ML
# Job Title: Store Driver, Cluster: ML
# Job Title: Asian Field Sales Representative- Fairfield County/Southern CT, Cluster: ML
# Job Title: Technical Curriculum Developer, Cluster: ML
# Job Title: Long Term Supply Planner, Cluster: ML

# %% [markdown]
# From the visulaistion above we can see some of the jobs that currently categorised as ML related. We need a better model and we need to train a proper classification algorithm for this task. We can't simply realy on clustering with the augmented features as we did in this notebook.
